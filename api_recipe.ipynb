# %%
import requests
import pandas as pd

# %%
from requests.auth import HTTPBasicAuth

# Replace 'YOUR_USERNAME' and 'YOUR_PASSWORD' with your actual credentials
username = "YOUR_USERNAME"
password = "YOUR_PASSWORD"
url = "https://spoonacular.com/food-api"

# Make a GET request to the API with Basic Authentication
response = requests.get(url, auth=HTTPBasicAuth(username, password))
response.status_code
# Out:
# 200

# %% [markdown]
# ### Apple Recipes

# %%
#recipes with apples
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=apples&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 673463,
#   'title': 'Slow Cooker Apple Pork Tenderloin',
#   'image': 'https://spoonacular.com/recipeImages/673463-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 2,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 6008,
#     'amount': 2.0,
#     'unit': 'cups',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Canned and Jarred',
#     'name': 'beef broth',
#     'original': '2 cups beef broth',
#     'originalName': 'beef broth',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/beef-broth.png'},
#    {'id': 10218,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': 'pork tenderloin',
#     'original': 'Pork Tenderloin',
#     'originalName': 'Pork Tenderloin',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/pork-tenderloin-raw.png'}],
# ...

# %%
##Recipe: Slow Cooker Apple Pork Tenderloin
#Recipe: Slow Cooked Applesauce
#Recipe: Baked Cinnamon Apple Slices
#Recipe: Easiest Breakfast Ever: Sunny Fruit Parfait

apple_recipe_list = []

apple_recipe_urls = [
    "https://api.spoonacular.com/recipes/673463/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/660261/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/633547/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/716433/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]

for url in apple_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        apple_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

apple_recipe_df = pd.DataFrame(apple_recipe_list)

apple_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True       True        False  False        False
# 1        True   True        True       True        False  False        False
# 2        True   True        True       True        False  False        False
# 3        True  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ... cuisines  \
# 0        False      False                         6  ...       []
# 1        False      False                         0  ...       []
# 2        False      False                         0  ...       []
# 3        False      False                         0  ...       []
#
#                                  dishTypes  \
# 0  [lunch, main course, main dish, dinner]
# 1                              [side dish]
# 2                              [side dish]
# 3                                       []
#
# ...

# %%
#Save the dataframe:
apple_recipe_df.to_csv("apple_recipes.csv", index=False)

# %% [markdown]
# ### Avocado Recipes

# %%
#recipes with avocado
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=avocado&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 633167,
#   'title': 'Avocado Tomato & Mozzarella Panini/sandwiches',
#   'image': 'https://spoonacular.com/recipeImages/633167-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 18029,
#     'amount': 8.0,
#     'unit': 'slices',
#     'unitLong': 'slices',
#     'unitShort': 'slice',
#     'aisle': 'Bakery/Bread',
#     'name': 'bread',
#     'original': '8 slices french bread',
#     'originalName': 'french bread',
#     'meta': ['french'],
#     'extendedName': 'french bread',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/crusty-bread.jpg'},
#    {'id': 1026,
#     'amount': 0.5,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Cheese',
#     'name': 'mozzarella',
#     'original': '1/2 cup grated mozzarella about',
#     'originalName': 'grated mozzarella about',
#     'meta': ['grated'],
# ...

# %%
#Recipe: Avocado Tomato & Mozzarella Panini/sandwiches
#Recipe: Banana Chocolate Pudding
#Recipe: Jamie's Guacamole
#Recipe: Avocado chocolate truffles

avocado_recipe_list = []

avocado_recipe_urls = [
    "https://api.spoonacular.com/recipes/633167/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/634048/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/648439/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/1697397/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]

for url in avocado_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        avocado_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

avocado_recipe_df = pd.DataFrame(avocado_recipe_list)

avocado_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False        False
# 1        True   True        True       True        False  False        False
# 2        True   True        True       True        False  False        False
# 3        True   True        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        16  ...
# 1        False      False                        12  ...
# 2        False      False                         2  ...
# 3        False      False                         3  ...
#
#                                            dishTypes  \
# 0            [lunch, main course, main dish, dinner]
# 1                                                 []
# 2  [antipasti, condiment, starter, snack, appetiz...
# 3                                        [side dish]
#
# ...

# %%
#Save the dataframe:
avocado_recipe_df.to_csv("avocado_recipes.csv", index=False)

# %% [markdown]
# ### Red kidney beans Recipes

# %%
#beans recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=navy-beans&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Smoky Baked Beans
#Recipe: Baked Bean
#Recipe: Navy Bean Soup
#Recipe: Smokin' Willy Barbecue Baked Beans

beans_recipe_list = []

beans_recipe_urls = [
    "https://api.spoonacular.com/recipes/660402/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/633453/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/652855/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/660401/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]

for url in beans_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        beans_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

beans_recipe_df = pd.DataFrame(beans_recipe_list)

beans_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True       True        False  False        False
# 1        True   True        True       True        False  False        False
# 2       False  False        True       True         True  False        False
# 3       False  False        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        29  ...
# 1        False      False                        35  ...
# 2        False      False                         4  ...
# 3        False      False                        79  ...
#
#                                              summary         cuisines  \
# 0  Smoky Baked Beans is a <b>gluten free and dair...               []
# 1  If you want to add more <b>gluten free, dairy ...               []
# 2  You can never have too many main course recipe...               []
# ...

# %%
#Save the dataframe:
beans_recipe_df.to_csv("beans_recipes.csv", index=False)

# %% [markdown]
# ### Bread Recipes

# %%
#bread recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=bread&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 661741,
#   'title': 'Strawberry and Chocolate Chip Panini',
#   'image': 'https://spoonacular.com/recipeImages/661741-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 9316,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'strawberries',
#     'original': 'Sliced strawberries',
#     'originalName': 'Sliced strawberries',
#     'meta': ['sliced'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/strawberries.png'},
#    {'id': 99278,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Baking',
#     'name': 'chocolate chips- handful',
#     'original': 'Chocolate chips- handful',
#     'originalName': 'Chocolate chips- handful',
#     'meta': [],
# ...

# %%
#Recipe: My Favourite Ricotta Sandwich
#Recipe: Kale Bruschetta
#Recipe: Avocado Tomato & Mozzarella Panini/sandwiches
#Recipe: Grilled Ham and Swiss Sandwich

bread_recipe_list = []

bread_recipe_urls = [
    "https://api.spoonacular.com/recipes/652861/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/633167/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/648715/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/645733/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]

for url in bread_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        bread_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

bread_recipe_df = pd.DataFrame(bread_recipe_list)

bread_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False       True        False  False        False
# 1        True  False       False      False        False  False        False
# 2        True   True       False       True        False  False        False
# 3       False  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         9  ...
# 1        False      False                        16  ...
# 2        False      False                         4  ...
# 3        False      False                         9  ...
#
#                              cuisines  \
# 0                                  []
# 1                                  []
# 2  [Mediterranean, Italian, European]
# 3                                  []
#
#                                            dishTypes  \
# ...

# %%
#Save the dataframe:
bread_recipe_df.to_csv("bread_recipes.csv", index=False)

# %% [markdown]
# ### Cheese Recipes

# %%
#cheese recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=cheese&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 661447,
#   'title': 'Square Deviled Eggs',
#   'image': 'https://spoonacular.com/recipeImages/661447-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 1129,
#     'amount': 6.0,
#     'unit': 'servings',
#     'unitLong': 'servings',
#     'unitShort': 'servings',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'eggs',
#     'original': 'Hard boiled eggs',
#     'originalName': 'Hard boiled eggs',
#     'meta': ['hard', 'boiled'],
#     'extendedName': 'cooked eggs',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/hard-boiled-egg.png'},
#    {'id': 10151,
#     'amount': 6.0,
#     'unit': 'servings',
#     'unitLong': 'servings',
#     'unitShort': 'servings',
#     'aisle': 'Meat',
#     'name': 'ham',
#     'original': 'Ham',
#     'originalName': 'Ham',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ham-whole.jpg'}],
# ...

# %%
#Recipe: Peas And Tarragon With Fresh Goat Cheese
#Recipe: Grilled Figs With Brie and Prosciutto
#Recipe: Goat Cheese Stuffed Bacon Wrapped Jalapeno Appetizer
#Recipe: Tater Tot Chili Cheese Casserole

cheese_recipe_list = []

cheese_recipe_urls = [
    "https://api.spoonacular.com/recipes/655477/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/645708/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/644958/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/1416203/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in cheese_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        cheese_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

cheese_recipe_df = pd.DataFrame(cheese_recipe_list)

cheese_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1       False  False        True      False        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         0  ...
# 1        False      False                         1  ...
# 2        False      False                         6  ...
# 3        False      False                         5  ...
#
#                                              summary    cuisines  \
# 0  Peas And Tarragon With Fresh Goat Cheese requi...          []
# 1  The recipe Grilled Figs With Brie and Prosciut...          []
# 2  The recipe Goat Cheese Stuffed Bacon Wrapped J...          []
# ...

# %%
#Save the dataframe:
cheese_recipe_df.to_csv("cheese_recipes.csv", index=False)

# %% [markdown]
# ### Eggs Recipes

# %%
#eggs recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=egg&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 661447,
#   'title': 'Square Deviled Eggs',
#   'image': 'https://spoonacular.com/recipeImages/661447-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 1017,
#     'amount': 6.0,
#     'unit': 'servings',
#     'unitLong': 'servings',
#     'unitShort': 'servings',
#     'aisle': 'Cheese',
#     'name': 'cream cheese',
#     'original': 'Cream cheese',
#     'originalName': 'Cream cheese',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cream-cheese.jpg'},
#    {'id': 10151,
#     'amount': 6.0,
#     'unit': 'servings',
#     'unitLong': 'servings',
#     'unitShort': 'servings',
#     'aisle': 'Meat',
#     'name': 'ham',
#     'original': 'Ham',
#     'originalName': 'Ham',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ham-whole.jpg'}],
#   'usedIngredients': [{'id': 1129,
#     'amount': 6.0,
#     'unit': 'servings',
# ...

# %%
#Recipe: Square Deviled Eggs
#Recipe: The Scotch Egg
#Recipe: Easy Cheesy Scrambled Eggs
#Recipe: Bread Omlette

eggs_recipe_list = []

eggs_recipe_urls = [
    "https://api.spoonacular.com/recipes/661447/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/663338/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/641890/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/635964/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in eggs_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        eggs_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

eggs_recipe_df = pd.DataFrame(eggs_recipe_list)

eggs_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True      False        False  False        False
# 1       False  False       False       True        False  False        False
# 2        True  False        True      False        False  False        False
# 3        True  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         6  ...
# 1        False      False                        21  ...
# 2        False      False                         8  ...
# 3        False      False                        26  ...
#
#                                              summary    cuisines  \
# 0  If you have around <b>45 minutes</b> to spend ...  [American]
# 1  The Scotch Egg takes around <b>45 minutes</b> ...          []
# 2  Easy Cheesy Scrambled Eggs is a <b>gluten free...          []
# ...

# %%
#Save the dataframe:
eggs_recipe_df.to_csv("eggs_recipes.csv", index=False)

# %% [markdown]
# ### Flour Recipes

# %%
#flour recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=flour&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 715381,
#   'title': 'Creamy Lime Pie Square Bites',
#   'image': 'https://spoonacular.com/recipeImages/715381-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 0,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 10018617,
#     'amount': 1.0,
#     'unit': 'cup',
#     'unitLong': 'cup',
#     'unitShort': 'cup',
#     'aisle': 'Baking',
#     'name': 'graham cracker crumbs',
#     'original': '1 cup crushed graham cracker crumbs',
#     'originalName': 'crushed graham cracker crumbs',
#     'meta': ['crushed'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/graham-crackers.jpg'},
#    {'id': 1009159,
#     'amount': 2.0,
#     'unit': 'drop',
#     'unitLong': 'drops',
#     'unitShort': 'drop',
#     'aisle': 'Produce',
#     'name': 'lime zest',
#     'original': '2 drop Lime essential oil (this is the brand I use) OR if not using essential oils, use 1 Tbsp grated lime zest.',
# ...

# %%
#Recipe: Creamy Lime Pie Square Bites
#Recipe: Lemon Bars
#Recipe: Classic scones
#Recipe: Yorkshire Pudding

flour_recipe_list = []

flour_recipe_urls = [
    "https://api.spoonacular.com/recipes/715381/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/715477/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/639637/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/665573/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
    ]
    

for url in flour_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        flour_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

flour_recipe_df = pd.DataFrame(flour_recipe_list)

flour_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False         True
# 1        True  False       False      False        False  False         True
# 2        True  False       False      False        False  False         True
# 3       False  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        26  ...
# 1        False      False                        37  ...
# 2        False      False                        14  ...
# 3        False      False                         2  ...
#
#                                  cuisines                          dishTypes  \
# 0                                      []                          [dessert]
# 1                                      []                          [dessert]
# ...

# %%
#Save the dataframe:
flour_recipe_df.to_csv("flour_recipes.csv", index=False)

# %% [markdown]
# ### Ham Recipes

# %%
#ham recipes
#rl = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=ham&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 652354,
#   'title': 'Monte Cristo Egg Rolls',
#   'image': 'https://spoonacular.com/recipeImages/652354-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 2,
#   'missedIngredientCount': 4,
#   'missedIngredients': [{'id': 7259,
#     'amount': 3.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Meat',
#     'name': 'deli turkey',
#     'original': '3 Deli Sliced Smoked Turkey',
#     'originalName': 'Deli Sliced Smoked Turkey',
#     'meta': ['smoked', 'sliced'],
#     'extendedName': 'smoked deli turkey',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/deli-turkey.jpg'},
#    {'id': 18368,
#     'amount': 8.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Ethnic Foods',
#     'name': 'egg roll wraps',
#     'original': '8 Egg Roll Wraps',
#     'originalName': 'Egg Roll Wraps',
#     'meta': [],
# ...

# %%
#Recipe: Monte Cristo Egg Rolls
#Recipe: Potatoes With Sauerkraut and Crunchy Smoked Ham
#Recipe: Pecan-Baked Ham
#Recipe: Involtini Di Pollo - Ham and Cheese Stuffed Chicken Rolls

ham_recipe_list = []

ham_recipe_urls = [
    "https://api.spoonacular.com/recipes/652354/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/657037/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/655540/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/647956/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
    ]
    

for url in ham_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        ham_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

ham_recipe_df = pd.DataFrame(ham_recipe_list)

ham_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False        True       True        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         5  ...
# 1        False      False                        10  ...
# 2        False      False                        12  ...
# 3        False      False                        11  ...
#
#                                              summary          cuisines  \
# 0  Monte Cristo Egg Rolls might be a good recipe ...  [Chinese, Asian]
# 1  Potatoes With Sauerkraut and Crunchy Smoked Ha...                []
# 2  Pecan-Baked Ham could be just the <b>gluten fr...                []
# ...

# %%
#Save the dataframe:
ham_recipe_df.to_csv("ham_recipes.csv", index=False)

# %% [markdown]
# ### Yogurt Recipes

# %%
#iogurt recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=yogurt&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 716422,
#   'title': 'Caramelized Onion Dip',
#   'image': 'https://spoonacular.com/recipeImages/716422-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 10211282,
#     'amount': 0.6666667,
#     'unit': 'c',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce',
#     'name': 'caramelized onions',
#     'original': '2/3c caramelized onions',
#     'originalName': 'caramelized onions',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'},
#    {'id': 11156,
#     'amount': 2.0,
#     'unit': 'T',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'chives',
#     'original': 'about 2T chopped fresh chives',
#     'originalName': 'about chopped fresh chives',
#     'meta': ['fresh', 'chopped'],
#     'extendedName': 'fresh chives',
# ...

# %%
#Recipe: Caramelized Onion Dip
#Recipe: Dulce De Leche Swirled Amaretto Frozen Yogurt
#Recipe: Melt Your Heart
#Recipe: Balsamic Vinaigrette Dressing

yogurt_recipe_list = []

yogurt_recipe_urls = [
    "https://api.spoonacular.com/recipes/716422/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/641732/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/665823/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/633950/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
    ]
    

for url in yogurt_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        yogurt_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

yogurt_recipe_df = pd.DataFrame(yogurt_recipe_list)

yogurt_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1        True  False        True      False        False  False        False
# 2        True  False        True      False        False  False        False
# 3        True  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         2  ...
# 1        False      False                         1  ...
# 2        False      False                         2  ...
# 3        False      False                         2  ...
#
#                                              summary  cuisines  \
# 0  Caramelized Onion Dip is a hor d'oeuvre that s...        []
# 1  You can never have too many dessert recipes, s...        []
# 2  If you have around <b>45 minutes</b> to spend ...        []
# ...

# %%
#Save the dataframe:
yogurt_recipe_df.to_csv("yogurt_recipes.csv", index=False)

# %% [markdown]
# ### Chicken Recipes

# %%
#chicken recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=chicken&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 640803,
#   'title': 'Crispy Buttermilk Fried Chicken',
#   'image': 'https://spoonacular.com/recipeImages/640803-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 2028,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'paprika',
#     'original': '1 teaspoon paprika',
#     'originalName': 'paprika',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/paprika.jpg'},
#    {'id': 1230,
#     'amount': 1.0,
#     'unit': 'cup',
#     'unitLong': 'cup',
#     'unitShort': 'cup',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'buttermilk',
#     'original': '1 cup buttermilk',
#     'originalName': 'buttermilk',
#     'meta': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/buttermilk.jpg'}],
#   'usedIngredients': [{'id': 5006,
# ...

# %%
#Recipe: Crispy Buttermilk Fried Chicken
#Recipe: Zucchini Chicken Omelette
#Recipe: Lemon and Garlic Slow Roasted Chicken
#Recipe: Slow Cooker Rosemary Whole Chicken

chicken_recipe_list = []

chicken_recipe_urls = [
    "https://api.spoonacular.com/recipes/640803/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/665734/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/649495/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/715525/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
    ]
    

for url in chicken_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        chicken_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

chicken_recipe_df = pd.DataFrame(chicken_recipe_list)

chicken_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False        True       True        False  False        False
# 2       False  False        True       True        False  False        False
# 3       False  False        True       True        False  False         True
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        11  ...
# 1        False       True                         5  ...
# 2        False      False                         9  ...
# 3        False      False                        17  ...
#
#                                              summary    cuisines  \
# 0  You can never have too many Southern recipes, ...  [Southern]
# 1  Zucchini Chicken Omelette is a main course tha...          []
# 2  Lemon and Garlic Slow Roasted Chicken might be...          []
# ...

# %%
#Save the dataframe:
chicken_recipe_df.to_csv("chicken_recipes.csv", index=False)

# %% [markdown]
# ### Milk Recipes

# %%
#milk recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=milk&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Caramel Flan
#Recipe: Homemade Strawberry Shake
#Recipe: Nutella Buttercream Cupcakes with Hidden Cadbury Egg
#Recipe: Vanilla Panna Cotta with Chocolate Ganache

milk_recipe_list = []

milk_recipe_urls = [
    "https://api.spoonacular.com/recipes/649419/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/715574/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/991625/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/664327/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
    ]
    

for url in milk_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        milk_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

milk_recipe_df = pd.DataFrame(milk_recipe_list)

milk_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1       False  False        True      False        False  False        False
# 2        True  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         6  ...
# 1        False      False                         7  ...
# 2        False      False                         7  ...
# 3        False      False                         0  ...
#
#                                              summary  \
# 0  Leche Flan (Caramel Flan) might be just the de...
# 1  Homemade Strawberry Shake takes roughly <b>45 ...
# 2  The recipe Nutella Buttercream Cupcakes with H...
# 3  Vanilla Panna Cotta with Chocolate Ganache cou...
#
# ...

# %%
#Save the dataframe:
milk_recipe_df.to_csv("milk_recipes.csv", index=False)

# %% [markdown]
# ### Mushrooms Recipe

# %%
#mushrooms recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=mushrooms&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Alouette Stuffed Mushroom Caps
#Recipe: Funghetti Trifolati
#Recipe: Baked Mushroom Caps
#Recipe: Grilled Mushrooms Salad

mushrooms_recipe_list = []

mushrooms_recipe_urls = [
    "https://api.spoonacular.com/recipes/632252/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/644094/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/633678/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/645776/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in mushrooms_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        mushrooms_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

mushrooms_recipe_df = pd.DataFrame(mushrooms_recipe_list)

mushrooms_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True       False       True        False  False        False
# 1        True   True        True       True        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         0  ...
# 1        False      False                         3  ...
# 2        False      False                        10  ...
# 3        False      False                         5  ...
#
#                                              summary  cuisines  \
# 0  You can never have too many hor d'oeuvre recip...        []
# 1  Funghetti Trifolati could be just the <b>glute...        []
# 2  Baked Mushroom Caps could be just the <b>glute...        []
# ...

# %%
#Save the dataframe:
mushrooms_recipe_df.to_csv("mushrooms_recipes.csv", index=False)

# %% [markdown]
# ### Oliveoil Recipes

# %%
#oliveoil recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=olive-oil&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Olive Tapenade Flatbread
#Recipe: Basil, Olive and Feta Foccacia
#Recipe: Greek Side Salad
#Recipe: Garlic Oregano Olive Tapenade

oliveoil_recipe_list = []

oliveoil_recipe_urls = [
    "https://api.spoonacular.com/recipes/1098351/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/634441/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/645348/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/1095689/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in oliveoil_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        oliveoil_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

oliveoil_recipe_df = pd.DataFrame(oliveoil_recipe_list)

oliveoil_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False        False
# 1        True  False       False      False        False  False        False
# 2        True  False        True      False        False  False        False
# 3       False  False        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        13  ...
# 1        False      False                        10  ...
# 2        False      False                         8  ...
# 3        False      False                        13  ...
#
#                                              summary  \
# 0  If you want to add more <b>lacto ovo vegetaria...
# 1  Basil, Olive and Feta Foccacia takes around <b...
# 2  Greek Side Salad is a hor d'oeuvre that serves...
# 3  Garlic Oregano Olive Tapenade takes about <b>4...
#
# ...

# %%
#Save the dataframe:
oliveoil_recipe_df.to_csv("oliveoil_recipes.csv", index=False)

# %% [markdown]
# ### Pasta Recipes

# %%
#pasta recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=pasta&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Bruschetta Style Pork & Pasta
#Recipe: Penne with Goat Cheese and Basil
#Recipe: Linguine With Chick Peas and Bacon
#Recipe: Spaghetti With Smoked Salmon and Prawns

pasta_recipe_list = []

pasta_recipe_urls = [
    "https://api.spoonacular.com/recipes/715538/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/655589/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/650132/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/660837/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in pasta_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        pasta_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

pasta_recipe_df = pd.DataFrame(pasta_recipe_list)

pasta_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1        True  False       False      False        False  False        False
# 2       False  False       False      False        False  False        False
# 3       False  False       False       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        15  ...
# 1        False      False                         4  ...
# 2        False      False                        24  ...
# 3        False      False                         1  ...
#
#                              cuisines  \
# 0  [Mediterranean, Italian, European]
# 1                                  []
# 2                                  []
# 3                                  []
#
#                                            dishTypes  \
# ...

# %%
#Save the dataframe:
pasta_recipe_df.to_csv("pasta_recipes.csv", index=False)

# %% [markdown]
# ### Potatoes Recipes

# %%
#potatoes recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=potatoes&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Homemade Garlic and Basil French Fries
#Recipe: Pan Fried Potato Wedges
#Recipe: Oven Potatoes
#Recipe: Parmesan Mashed Potatoes

potatoes_recipe_list = []

potatoes_recipe_urls = [
    "https://api.spoonacular.com/recipes/715594/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/1099404/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/654213/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/654679/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in potatoes_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        potatoes_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

potatoes_recipe_df = pd.DataFrame(potatoes_recipe_list)

potatoes_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True       False       True        False  False         True
# 1        True   True        True       True        False  False        False
# 2        True   True        True       True         True  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...    cuisines  \
# 0        False      False                        20  ...  [American]
# 1        False      False                         8  ...          []
# 2        False      False                        43  ...          []
# 3        False      False                        27  ...          []
#
#                                  dishTypes  \
# 0                              [side dish]
# 1                              [side dish]
# 2  [lunch, main course, main dish, dinner]
# 3                              [side dish]
#
# ...

# %%
#Save the dataframe:
potatoes_recipe_df.to_csv("potatoes_recipes.csv", index=False)

# %% [markdown]
# ### Rice Recipes

# %%
#rice recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=rice&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 648742,
#   'title': 'Kappa Maki',
#   'image': 'https://spoonacular.com/recipeImages/648742-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 11206,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'japanese cucumber',
#     'original': '2 Japanese cucumber, cut into long sticks',
#     'originalName': 'Japanese cucumber, cut into long sticks',
#     'meta': ['cut into long sticks'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cucumber.jpg'},
#    {'id': 11446,
#     'amount': 4.0,
#     'unit': 'inches sheets',
#     'unitLong': 'inches sheets',
#     'unitShort': 'inches sheets',
#     'aisle': 'Ethnic Foods',
#     'name': 'of nori',
#     'original': '4 inches sheets of nori (dried seaweed), cut half',
#     'originalName': 'inches sheets of nori (dried seaweed), cut half',
# ...

# %%
#Recipe: Cardamon Infused Black Rice Pudding with Coconut Milk
#Recipe: Cumin-Scented Basmati Rice Pilaf
#Recipe: Rice Honey Bread
#Recipe: Wild Rice With Bacon, Mushrooms & Green Onions

rice_recipe_list = []

rice_recipe_urls = [
    "https://api.spoonacular.com/recipes/637095/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/641034/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/658251/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/665344/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"

]
    

for url in rice_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        rice_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

rice_recipe_df = pd.DataFrame(rice_recipe_list)

rice_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True        True       True        False  False        False
# 1        True  False        True      False        False  False        False
# 2        True  False       False      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False       True                        12  ...
# 1        False      False                         6  ...
# 2        False      False                        26  ...
# 3        False      False                         5  ...
#
#                                              summary  cuisines  \
# 0  Cardamon Infused Black Rice Pudding with Cocon...        []
# 1  Cumin-Scented Basmati Rice Pilaf might be just...        []
# 2  Rice Honey Bread could be just the <b>lacto ov...        []
# ...

# %%
#Save the dataframe:
rice_recipe_df.to_csv("rice_recipes.csv", index=False)

# %% [markdown]
# ### Salad Recipes

# %%
#salad recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=salad&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Garlicky Kale
#Recipe: Kale With Red Onion
#Recipe: Black Truffle Caesar Salad
#Recipe: Kale Bruschetta

salad_recipe_list = []

salad_recipe_urls = [
    "https://api.spoonacular.com/recipes/644387/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/648729/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/635161/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/648715/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in salad_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        salad_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

salad_recipe_df = pd.DataFrame(salad_recipe_list)

salad_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True        True       True         True  False        False
# 1        True   True        True       True        False  False        False
# 2       False  False        True       True        False  False        False
# 3        True   True       False       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         5  ...
# 1        False      False                         0  ...
# 2        False       True                         3  ...
# 3        False      False                         4  ...
#
#                                              summary  \
# 0  Garlicky Kale requires approximately <b>45 min...
# 1  Kale With Red Onion is a side dish that serves...
# 2  Black Truffle Caesar Salad might be a good rec...
# 3  Kale Bruschettan is a <b>dairy free, lacto ovo...
#
# ...

# %%
#Save the dataframe:
salad_recipe_df.to_csv("salad_recipes.csv", index=False)

# %% [markdown]
# ### Salmon Recipes

# %%
#salmon recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=salmon&number=10"

#response = requests.get(url)
#response.json()
# Out:
# [{'id': 660837,
#   'title': 'Spaghetti With Smoked Salmon and Prawns',
#   'image': 'https://spoonacular.com/recipeImages/660837-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 2045,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'dill- roughly cut',
#     'original': '2 tablespoons Fresh dill- roughly cut',
#     'originalName': 'Fresh dill- roughly cut',
#     'meta': ['fresh'],
#     'extendedName': 'fresh dill- roughly cut',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/dill.jpg'},
#    {'id': 11215,
#     'amount': 1.0,
#     'unit': 'tablespoon',
#     'unitLong': 'tablespoon',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'garlic- or',
#     'original': '1 tablespoon Garlic- chopped or sliced',
# ...

# %%
#Recipe: Green Beans with Pearl Onions and Salmon
#Recipe: Wild Salmon Cakes
#Recipe: Smoked Salmon & Ricotta Wraps
#Recipe: an-seared salmon with brown butter lime sauce and roasted asparagus

salmon_recipe_list = []

salmon_recipe_urls = [
    "https://api.spoonacular.com/recipes/645418/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/665348/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/660588/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/654476/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in salmon_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        salmon_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

salmon_recipe_df = pd.DataFrame(salmon_recipe_list)

salmon_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True      False        False  False        False
# 1       False  False       False       True        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                         8  ...
# 1        False      False                         4  ...
# 2        False      False                         5  ...
# 3        False      False                        24  ...
#
#                                              summary  cuisines  \
# 0  If you have approximately <b>45 minutes</b> to...        []
# 1  Wild Salmon Cakes might be just the main cours...        []
# 2  Smoked Salmon & Ricotta Wraps is a main course...        []
# ...

# %%
#Save the dataframe:
salmon_recipe_df.to_csv("salmon_recipes.csv", index=False)

# %% [markdown]
# ### Spinach Recipes

# %%
#spinach recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=spinach&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: Simple Spinach and Tomato Frittata
#Recipe: Skinny Green Monster Smoothie
#Recipe: Vegetable Tart With Goat Cheese
#Recipe: Becky Bergstrom's Spinach Balls

spinach_recipe_list = []

spinach_recipe_urls = [
    "https://api.spoonacular.com/recipes/769775/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/660227/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/664615/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/634556/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in spinach_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        spinach_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

spinach_recipe_df = pd.DataFrame(spinach_recipe_list)

spinach_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False        True      False        False  False        False
# 2        True  False       False      False        False  False        False
# 3       False  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ... cuisines  \
# 0        False      False                         3  ...       []
# 1        False      False                         5  ...       []
# 2        False      False                        13  ...       []
# 3        False      False                         4  ...       []
#
#                                            dishTypes                   diets  \
# 0  [lunch, main course, morning meal, brunch, mai...                      []
# 1  [morning meal, brunch, beverage, breakfast, dr...           [gluten free]
# ...

# %%
#Save the dataframe:
spinach_recipe_df.to_csv("spinach_recipes.csv", index=False)

# %% [markdown]
# ### Veggies Recipes

# %%
#veggies recipes
#url = "https://api.spoonacular.com/recipes/findByIngredients?apiKey=3567a368fd5840cca26a4181b69a2e17&ingredients=veggies&number=10"

#response = requests.get(url)
#response.json()

# %%
#Recipe: 4 Ingredient Chicken Pot Pie
#Recipe: Vegetable Dip
#Recipe: Peas And Tarragon With Fresh Goat Cheese
#Recipe: Kappa Maki

veggies_recipe_list = []

veggies_recipe_urls = [
    "https://api.spoonacular.com/recipes/631868/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/664547/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/655477/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false",
    "https://api.spoonacular.com/recipes/648742/information?apiKey=3567a368fd5840cca26a4181b69a2e17&includeNutrition=false"
]
    

for url in veggies_recipe_urls:
    response = requests.get(url)
    if response.status_code == 200:
        recipe_data = response.json()
        veggies_recipe_list.append(recipe_data)
    else:
        print(f"Request for {url} failed with status code {response.status_code}")

veggies_recipe_df = pd.DataFrame(veggies_recipe_list)

veggies_recipe_df
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False       True        False  False        False
# 1        True  False        True      False         True  False        False
# 2        True  False        True      False        False  False        False
# 3        True   True        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ... cuisines  \
# 0        False      False                        17  ...       []
# 1        False      False                         4  ...       []
# 2        False      False                         0  ...       []
# 3        False       True                         9  ...       []
#
#                                            dishTypes  \
# 0            [lunch, main course, main dish, dinner]
# 1  [antipasti, condiment, starter, snack, appetiz...
# 2                                        [side dish]
# ...

# %%
#Save the dataframe:
veggies_recipe_df.to_csv("veggies_recipes.csv", index=False)
