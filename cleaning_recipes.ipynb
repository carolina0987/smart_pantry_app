# %%
import pandas as pd
import re
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Apple Recipes

# %%
apple_recipes = pd.read_csv("apple_recipes.csv")
apple_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True       True        False  False        False
# 1        True   True        True       True        False  False        False
# 2        True   True        True       True        False  False        False
# 3        True  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints    gaps  \
# 0        False      False                         6      no
# 1        False      False                         0      no
# 2        False      False                         0  GAPS_6
# 3        False      False                         0      no
#
#    preparationMinutes  cookingMinutes  aggregateLikes  healthScore  \
# 0                  -1              -1               0           18
# 1                  -1              -1               2            0
# 2                  -1              -1               1            4
# ...

# %%
apple_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "license", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
def remove_html_tags(text):
    if isinstance(text, str):
        clean = re.compile('<.*?>')
        return re.sub(clean, '', text)
    return text

apple_recipes["instructions"] = apple_recipes["instructions"].apply(remove_html_tags)

apple_recipes
# Out:
#                                          title  readyInMinutes  \
# 0            Slow Cooker Apple Pork Tenderloin              45
# 1                       Slow Cooked Applesauce              45
# 2                  Baked Cinnamon Apple Slices              45
# 3  Easiest Breakfast Ever: Sunny Fruit Parfait              45
#
#                                            sourceUrl  \
# 0  http://www.pinkwhen.com/slow-cooker-apple-pork...
# 1  https://www.foodista.com/recipe/XB3V6NRQ/slow-...
# 2  http://www.foodista.com/recipe/JQWGC7VW/baked-...
# 3  http://fullbellysisters.blogspot.com/2011/04/e...
#
#                                                diets  \
# 0                      ['gluten free', 'dairy free']
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...
# 2  ['gluten free', 'dairy free', 'paleolithic', '...
# 3  ['gluten free', 'lacto ovo vegetarian', 'primal']
#
#                                         instructions
# 0                                                NaN
# ...

# %%
# Define the lists of ingredients
ingredients_list: [
    ["Pork Tenderloin", "2 green apples", "cinnamon sugar (optional)", "2 cups beef broth", "apple slicer (optional)"],
    ["5 apples from a local tree", "1 cup water (more if necessary)", "3 tablespoons brown sugar", "1/2 teaspoon cinnamon", "pinch of nutmeg", "pinch of salt"],
    ["4 Apples Sliced and Peeled", "1/2 cup of Raisins", "1 1/2 tablespoons of Cinnamon", "2 tablespoons of melted butter"],
    ["yogurt", "chopped organic apple", "raisins", "sunflower seeds"]
]

apple_recipes["ingredients_list"] = ingredients_list

# %%
instruction = "To get started, take your pork tenderloin out of the package and rinse it clean. Take your two apples and slice and core them. Once your apples are sliced, sprinkle a little cinnamon sugar on them. Just a really light coat will do fine. Slice the pork tenderloin about 3/4 through and then insert the apple slices into the slits. Place remaining apple slices into the bottom of the crockpot. Place the tenderloins on top, and then add 2 cups beef broth. Cover and bake on high for 4 hours or on low for 8 hours."
apple_recipes.loc[0, "instructions"] = instruction

# %%
instruction = "Put all in a bowl, mix together and dig in! Try other dried fruit, like cranberries or blueberries; try different nuts or seeds, such as walnuts, almonds, chia, or pecans."
apple_recipes.loc[3, "instructions"] = instruction

# %%
apple_recipes["Product"] = "apple"

# %%
apple_recipes
# Out:
#                                          title  readyInMinutes  \
# 0            Slow Cooker Apple Pork Tenderloin              45
# 1                       Slow Cooked Applesauce              45
# 2                  Baked Cinnamon Apple Slices              45
# 3  Easiest Breakfast Ever: Sunny Fruit Parfait              45
#
#                                            sourceUrl  \
# 0  http://www.pinkwhen.com/slow-cooker-apple-pork...
# 1  https://www.foodista.com/recipe/XB3V6NRQ/slow-...
# 2  http://www.foodista.com/recipe/JQWGC7VW/baked-...
# 3  http://fullbellysisters.blogspot.com/2011/04/e...
#
#                                                diets  \
# 0                      ['gluten free', 'dairy free']
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...
# 2  ['gluten free', 'dairy free', 'paleolithic', '...
# 3  ['gluten free', 'lacto ovo vegetarian', 'primal']
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Avocado Recipes

# %%
avocado_recipes = pd.read_csv("avocado_recipes.csv")
avocado_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False        False
# 1        True   True        True       True        False  False        False
# 2        True   True        True       True        False  False        False
# 3        True   True        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints       gaps  \
# 0        False      False                        16         no
# 1        False      False                        12         no
# 2        False      False                         2  GAPS_FULL
# 3        False      False                         3         no
#
#    preparationMinutes  cookingMinutes  aggregateLikes  healthScore  \
# 0                  -1              -1               3           16
# 1                  -1              -1               1           44
# ...

# %%
avocado_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "license", "dairyFree", "author", "dishTypes"], inplace = True, axis = 1)

# %%
avocado_recipes
# Out:
#                                            title  readyInMinutes  \
# 0  Avocado Tomato & Mozzarella Panini/sandwiches              45
# 1                       Banana Chocolate Pudding              45
# 2                              Jamie's Guacamole              45
# 3                    Avocado chocolate truffles               40
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/5D3FD6GZ/avoca...
# 1  http://www.foodista.com/recipe/GQNT2SWV/banana...
# 2  https://www.foodista.com/recipe/3HZTSB8H/jamie...
# 3          https://spoonacular.com/app-1642232393346
#
#                                                diets  \
# 0                           ['lacto ovo vegetarian']
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...
# 2  ['gluten free', 'dairy free', 'paleolithic', '...
# 3  ['gluten free', 'dairy free', 'lacto ovo veget...
#
#                                         instructions
# ...

# %%
avocado_recipes["instructions"] = avocado_recipes["instructions"].apply(remove_html_tags)
avocado_recipes["instructions"] = avocado_recipes["instructions"].str.replace(r'\n\r', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\700179970.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   avocado_recipes["instructions"] = avocado_recipes["instructions"].str.replace(r'\n\r', ' ')

# %%
avocado_recipes.loc[0, "instructions"] = avocado_recipes.loc[0, "instructions"].replace('\n', ' ')

# %%
instructions = 'Note: needs 30 minutes in fridge. Boil a kettle of water for melting the chocolate in a double boiler. Blend the avocado into a smooth consistency. Coat: Prepare coating ingredients in a bowl (raw cocoa, dessicated coconut, or ground almonds). Cut wax paper to fit into a tray or plate. Cook: Break the chocolate into smaller pieces and melt it in a double boiler over a low heat. Add the salt and vanilla essence. Remove from the heat once the chocolate has melted. Add the chocolate and cocoa powder to the blender with the avocado. Add brown sugar, to taste. Blend or mix the chocolate and avocado mix through until you have a smooth, thick, pudding-like consistency. Transfer the food processor bowl to the fridge for about 30 minutes. After 30 minutes, check the consistency - if it is still too soft to handle, put in fridge for another 5-10 minutes. When solid enough to handle, scoop up a little bit of the stiffened chocolate with a teaspoon and roll it in your hands into a smooth ball. Transfer the ball to the coating and roll it until it is completely covered. Place the covered ball on a tray or plate. Place the chocolate truffles back in the fridge and keep it chilled until serving.'
avocado_recipes.loc[3, "instructions"] = instructions

# %%
ingredients_list = [
    ["1 avocado sliced", "8 slices french bread", "1 thin sliced tomato", "1/2 cup grated mozzarella", "butter for outside of panini"],
    ["4-5 bananas", "1 avocado", "1/3 cup cocoa powder", "1/2 cup peanut butter"],
    ["1 avocado", "1/4 large white onion", "1/4 medium tomato", "1/2 lime", "salt and pepper to taste"],
    ["1 avocado", "dark chocolate chips", "cocoa powder", "sal"]
]

avocado_recipes["ingredients_list"] = ingredients_list

# %%
avocado_recipes["Product"] = "avocado"

# %%
avocado_recipes
# Out:
#                                            title  readyInMinutes  \
# 0  Avocado Tomato & Mozzarella Panini/sandwiches              45
# 1                       Banana Chocolate Pudding              45
# 2                              Jamie's Guacamole              45
# 3                    Avocado chocolate truffles               40
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/5D3FD6GZ/avoca...
# 1  http://www.foodista.com/recipe/GQNT2SWV/banana...
# 2  https://www.foodista.com/recipe/3HZTSB8H/jamie...
# 3          https://spoonacular.com/app-1642232393346
#
#                                                diets  \
# 0                           ['lacto ovo vegetarian']
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...
# 2  ['gluten free', 'dairy free', 'paleolithic', '...
# 3  ['gluten free', 'dairy free', 'lacto ovo veget...
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Beans Recipes

# %%
beans_recipes = pd.read_csv("beans_recipes.csv")
beans_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True       True        False  False        False
# 1        True   True        True       True        False  False        False
# 2       False  False        True       True         True  False        False
# 3       False  False        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                        29   no                  -1
# 1        False      False                        35   no                  -1
# 2        False      False                         4   no                  -1
# 3        False      False                        79   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               5           19
# 1              -1               1           41
# 2              -1               1          100
# ...

# %%
beans_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "license", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
beans_recipes["instructions"] = beans_recipes["instructions"].apply(remove_html_tags)

# %%
beans_recipes["instructions"] = beans_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\4265763374.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   beans_recipes["instructions"] = beans_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions = "In a slow cooker combine all ingredients except salt. Cover and cook on low 2 to 4 hours stirring occasionally. Add salt to taste when beans are tender."
beans_recipes.loc[0, "instructions"] = instructions

# %%
instructions = "Put everything in a crockpot adding water to cover and cook on High for 5-6 hours. They get very thick cooked this way. Can also be baked covered in an oven 300°F or 150°C for 1 1/2 hours. Then simmer the beans in water for 45 min to 1 1/2 hours. Drain the beans and place in large baking dish add all other ingredients plus enough of the cooking liquid to barely cover the beans. If you find these too sweet just cut down on the sweeteners."
beans_recipes.loc[1, "instructions"] = instructions

# %%
instructions = "Sort and wash the beans. Add 6 cups water and soak the beans overnight. Drain the beans add ham bone and cover with water. Bring them to boil reduce heat and simmer for 1 hour. Add remaining ingredients simmer 1 hour until the beans are tender. Remove bone. Chop ham and return meat to soup"
beans_recipes.loc[2, "instructions"] = instructions

# %%
beans_recipes.loc[3, "instructions"] = beans_recipes.loc[3, "instructions"].replace(r'*', '°')

# %%
ingredients_list = [
    ["1 pound dried navy beans, rinsed and soaked overnight",
    "Water to cover",
    "1/3 cup dark molasses",
    "1/4 cup brown sugar, packed",
    "1 cup chopped sweet yellow onion",
    "3/4 pound salt pork, rinsed and cut into 1/2-inch cubes (1 12-ounce package)",
    "1 tablespoon Dijon mustard",
    "1 tablespoon liquid smoke",
    "Kosher salt to taste"],
    ["2 pounds Navy beans, soaked for 6-12 hours, drained and rinsed",
    "2 mediums Onions, finely chopped",
    "1 cup BBQ sauce (optional)",
    "1 cup Unsulphured molasses",
    "6 tablespoons Tamari",
    "6 tablespoons Pure maple syrup",
    "2 tablespoons Dry mustard",
    "2 teaspoons Salt"],
    ["1 pound dried navy beans",
    "1 meaty ham bone",
    "3 cups chopped celery",
    "3 cups shredded carrots",
    "1 inch onion chopped",
    "1 tablespoon dried parsley",
    "2 cloves minced garlic",
    "1/4 teaspoon tobasco sauce",
    "1 teaspoon salt",
    "1/4 teaspoon black pepper",
    ],
    ["1 pound Dry Navy beans",
    "1/2 pound Hickory smoked sausage, cut up thin",
    "1 pound Smoke sliced bacon",
    "1 cup chopped onions",
    "1 cup chopped bell pepper",
    "1/2 cup molasses",
    "1/2 cup pineapple juice",
    "1 cup packed dark brown sugar",
    "1 teaspoon French’s yellow mustard",
    "1 teaspoon allspice",
    "1 teaspoon kosher salt",
    "1 tablespoon Black pepper",
    "1 ounce chili powder",
    "2 cups diced tomatoes",
    "1 cup ketchup",
    "1 cup Your favorite Sweet and Spicy BBQ sauce"]]

beans_recipes["ingredients_list"] = ingredients_list

# %%
beans_recipes["Product"] = "beans"

# %%
beans_recipes
# Out:
#                                 title  readyInMinutes  \
# 0                   Smoky Baked Beans              45
# 1                          Baked Bean              45
# 2          My Favorite Navy Bean Soup              45
# 3  Smokin' Willy Barbecue Baked Beans              45
#
#                                            sourceUrl  \
# 0  http://www.foodista.com/recipe/MCLQKN4K/smoky-...
# 1  http://www.foodista.com/recipe/CZD23R54/baked-...
# 2  http://www.foodista.com/recipe/5X7YZGTZ/my-fav...
# 3  https://www.foodista.com/recipe/42GZ2S4B/smoki...
#
#                                                diets  \
# 0                      ['gluten free', 'dairy free']
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...
# 2                      ['gluten free', 'dairy free']
# 3                      ['gluten free', 'dairy free']
#
#                                         instructions  \
# 0  In a slow cooker combine all ingredients excep...
# ...

# %% [markdown]
# ## Bread Recipes

# %%
bread_recipes = pd.read_csv("bread_recipes.csv")
bread_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False       True        False  False        False
# 1        True  False       False      False        False  False        False
# 2        True   True       False       True        False  False        False
# 3       False  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         9   no                  -1
# 1        False      False                        16   no                  -1
# 2        False      False                         4   no                  -1
# 3        False      False                         9   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               1           24
# 1              -1               3           16
# 2              -1               1            1
# ...

# %%
bread_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "license", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
def replace(diets):
    if not diets or diets == '[]':  
        return "lacto ovo vegetarian"
    return diets

bread_recipes["diets"] = bread_recipes["diets"].apply(replace)

# %%
bread_recipes["instructions"] = bread_recipes["instructions"].apply(remove_html_tags)
bread_recipes["instructions"] = bread_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\1793533341.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   bread_recipes["instructions"] = bread_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions = "Take your slice of bread. Smear it with minarine or butter. Smear a thick layer of the sheep's ricotta, evenly onto the bread. Arrange your slices of the strawberries on top. Take your coffee spoon of the best Balsamic vinegar and drizzle it over your strawberries & the ricotta"
bread_recipes.loc[0, "instructions"] = instructions

# %%
instructions = "Clean kale, by removing the tough stems. Wash off and boil in salted water until tender. Drain well. Chop. Saute in olive oil with sliced garlic. Toast bread. Rub with raw garlic clove. Top with hot kale. Sprinkle with salt. Drizzle with Extra Virgin Olive Oil"
bread_recipes.loc[2, "instructions"] = instructions

# %%
instructions = "Melt butter in skillet. Stack sandwich like so: bread, ham, ham, ham, swiss, bread. Place sandwich in skillet, let brown. Adjust heat as needed. Remove the sandwich briefly from the skillet, add the other piece of butter and let it melt. Flip sandwich over and brown. Cook until cheese is melted. Eat hot."
bread_recipes.loc[3, "instructions"] = instructions

# %%
ingredients_list = [
    ["1 thicker slice of bread",
    "A bit of margarine or butter (unsalted)",
    "A thick layer of fresh sheep's ricotta",
    "3 fat strawberries, cleaned, green stuff cut out & cut up thicker slices",
    "1 coffee spoon of your best Balsamic vinegar"],
    ["1 ripe avocado sliced",
    "8 slices french bread",
    "1 thin sliced tomato",
    "1/2 cup grated mozzarella",
    "butter for outside of panini"],
    ["1 inch Kale",
    "Country-style bread, sliced for toast, thickly",
    "Extra Virgin Olive oil",
    "1 Garlic Clove",
    "Sea Salt"],
    ["2 Slices White Bread",
    "3 Pieces Thin Sliced Ham",
    "2 Slices Swiss Cheese",
    "2 pats of butter"]
]

bread_recipes["ingredients_list"] = ingredients_list

# %%
bread_recipes["Product"] = "bread"

# %%
bread_recipes
# Out:
#                                            title  readyInMinutes  \
# 0                  My Favourite Ricotta Sandwich              45
# 1  Avocado Tomato & Mozzarella Panini/sandwiches              45
# 2                                Kale Bruschetta              45
# 3                 Grilled Ham and Swiss Sandwich              45
#
#                                            sourceUrl  \
# 0  http://www.foodista.com/recipe/MPGH3KPY/my-fav...
# 1  https://www.foodista.com/recipe/5D3FD6GZ/avoca...
# 2  http://www.foodista.com/recipe/3MK8JYZR/kale-b...
# 3  http://www.foodista.com/recipe/HB2QCPZY/grille...
#
#                                              diets  \
# 0                                   ['dairy free']
# 1                         ['lacto ovo vegetarian']
# 2  ['dairy free', 'lacto ovo vegetarian', 'vegan']
# 3                             lacto ovo vegetarian
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Cheese Recipes

# %%
cheese_recipes = pd.read_csv("cheese_recipes.csv")
cheese_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1       False  False        True      False        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         0   no                  -1
# 1        False      False                         1   no                  -1
# 2        False      False                         6   no                  -1
# 3        False      False                         5   no                   5
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               1           24
# 1              -1               1            0
# 2              -1               1            1
# ...

# %%
cheese_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "license", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
cheese_recipes["instructions"] = cheese_recipes["instructions"].apply(remove_html_tags)
cheese_recipes["instructions"] = cheese_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\94853692.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   cheese_recipes["instructions"] = cheese_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
    ["1 pound Peas", "1 package 5.3 oz. Chavrie fresh goat cheese, Pyramid", "1 teaspoon Chopped tarragon"],
    ["2 figs per skewer", "1 square brie cheese per fig", "1 slice prosciutto per fig"],
    ["6 jalapenos", "4 ounces goat cheese", "6 slices thick sliced bacon"],
    ["2 cups chili", "2 cups tater tots", "1 cup shredded cheddar cheese"]]

cheese_recipes["ingredients_list"] = ingredients_list

# %%
cheese_recipes["Product"] = "cheese"

# %%
cheese_recipes
# Out:
#                                                title  readyInMinutes  \
# 0           Peas And Tarragon With Fresh Goat Cheese              45
# 1              Grilled Figs With Brie and Prosciutto              45
# 2  Goat Cheese Stuffed Bacon Wrapped Jalapeno App...              45
# 3                   Tater Tot Chili Cheese Casserole              40
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/SNJ64XV8/peas-...
# 1  https://www.foodista.com/recipe/RHB54ST3/grill...
# 2  http://www.foodista.com/recipe/JNCC5X34/goat-c...
# 3  https://www.pinkwhen.com/tater-tot-chili-chees...
#
#                                                diets  \
# 0  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 1                          ['gluten free', 'primal']
# 2                          ['gluten free', 'primal']
# 3                                    ['gluten free']
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Chicken Recipes

# %%
chicken_recipes = pd.read_csv("chicken_recipes.csv")
chicken_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False        True       True        False  False        False
# 2       False  False        True       True        False  False        False
# 3       False  False        True       True        False  False         True
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                        11   no                  -1
# 1        False       True                         5   no                  -1
# 2        False      False                         9   no                  -1
# 3        False      False                        17   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore   creditsText    sourceName  \
# 0              -1              53            4  foodista.com  foodista.com
# ...

# %%
chicken_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
chicken_recipes["instructions"] = chicken_recipes["instructions"].apply(remove_html_tags)
chicken_recipes["instructions"] = chicken_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\450723646.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   chicken_recipes["instructions"] = chicken_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions = "2 X 300g packets mushroom or italian style stir fry or stir fry vegetables of your own choice finely shredded. Trim the leg tips and wing tips from the chicken and remove any excess fat (keep the chicken fat if you are likely to make a confit in the next few days). Season the chicken inside and out. Separate the garlic into cloves but do not bother to peel them. Place about two thirds of the cloves inside the chicken and the rest in the bottom of the roasting tin sitting the chicken on top of them. Pare the zest from the lemons and cover it in plastic wrap for later use as a garnish. Rub the juice into the chicken inside and out then rub the olive oil over the breast. Roast the chicken quickly for 30 minutes then transfer it to the simmering ovenand cook for at least 4 hours. Stand for 10 to 15 minutes before carving or if you have left the chicken for six hours or more pulling the joints apart for serving. Heat a wok or large frying pan for 5 minutes on the floor of the roasting ovenwhile the chicken is standing. Transfer the wok to the boiling plateand add the sunflower oil. Stir fry the vegetables in the oil for 3 to 4 minutes then serve the chicken on the vegetables or mixed."
chicken_recipes.loc[2, "instructions"] = instructions

# %%
instructions = "Place balls of foil into the bottom of the slow cooker for the whole chicken to rest on while cooking. For maximum flavor, layer the bottom of the slow cooker with onion, lemon, and 1/2 cup of water. Once you have basted and seasoned the chicken, cook on low for 7-8 hours for best results. You can also cook this recipe on high for 4-5 hours if you need dinner on the table faster."
chicken_recipes.loc[3, "instructions"] = instructions

# %%
ingredients_list = [
    ["2 pounds chicken",
    "3/4 cup flour",
    "2 teaspoons salt",
    "1 teaspoon paprika",
    "1 teaspoon pepper",
    "1 cup buttermilk",
    "Vegetable oil (enough to cover chicken), about 1 quart"],
    ["3 Eggs",
    "1 tablespoon Water",
    "150 grams Zucchini, grated",
    "Salt and pepper to taste",
    "1 tablespoon Oil",
    "80 grams Milanese chicken leftover, diced"],
    ["1 large chicken weighing about 2.3kg",
    "2 bulbs garlic",
    "2 large lemons",
    "Salt and freshly ground black pepper",
    "1 tablespoon olive oil",
    "2 tablespoons sunflower oil"],
    ["1 whole chicken",
    "2-3 sprigs of fresh rosemary",
    "4-6 cloves of garlic",
    "1 lemon",
    "Salt and pepper to taste",
    "2 tablespoons olive oil"]
    ]

chicken_recipes["ingredients_list"] = ingredients_list

# %%
chicken_recipes["Product"] = "chicken"

# %%
chicken_recipes
# Out:
#                                    title  readyInMinutes  \
# 0        Crispy Buttermilk Fried Chicken              45
# 1              Zucchini Chicken Omelette              45
# 2  Lemon and Garlic Slow Roasted Chicken              45
# 3     Slow Cooker Rosemary Whole Chicken              45
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/G2QDD6GF/crisp...
# 1  https://www.foodista.com/recipe/TPJ6QNBY/zucch...
# 2  http://www.foodista.com/recipe/TSSQGG2V/lemon-...
# 3  http://www.pinkwhen.com/slow-cooker-rosemary-w...
#
#                                                diets  \
# 0                                                 []
# 1  ['gluten free', 'dairy free', 'fodmap friendly...
# 2  ['gluten free', 'dairy free', 'whole 30', 'ket...
# 3  ['gluten free', 'dairy free', 'paleolithic', '...
#
#                                         instructions  \
# 0  Mix flour, salt, paprika and pepper. Dip chick...
# ...

# %% [markdown]
# ## Eggs Recipes

# %%
eggs_recipes = pd.read_csv("eggs_recipes.csv")
eggs_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True      False        False  False        False
# 1       False  False       False       True        False  False        False
# 2        True  False        True      False        False  False        False
# 3        True  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         6   no                  -1
# 1        False      False                        21   no                  -1
# 2        False      False                         8   no                  -1
# 3        False      False                        26   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1              25            6
# 1              -1              10            7
# 2              -1               3            3
# ...

# %%
eggs_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
eggs_recipes["instructions"] = eggs_recipes["instructions"].apply(remove_html_tags)
eggs_recipes["instructions"] = eggs_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\2049950843.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   eggs_recipes["instructions"] = eggs_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions = "To make square hard boiled eggs, you'll need an Egg cuber or Square Egg Press. First boil your eggs, then slide the egg inside the press and screw the top down so it pushes the egg into the corners. Let the egg cool and remove it from the mold. For better results use medium size eggs. If you intend to prepare this for a party, I suggest you buy several cubers, this way you can boil and chill several eggs at a time, or it will take you a lot of time. To prepare hard boiled eggs, place eggs in a saucepan, cover with cold water and bring to a boil over medium heat. As soon as the water comes to a full boil, let the eggs boil for 5 minutes, and then remove from heat and let stand covered in hot water 10 minutes . Filling is made with cream cheese, ham and egg yolk."
eggs_recipes.loc[0, "instructions"] = instructions

# %%
instructions = "First, heat the pan until it's hot. Next, crack an egg into it. Stir it gently with a spoon. Then, place it on a slice of bread, apply some glue (Fevicol) if you prefer, and stick another slice on top. Flip it over."
eggs_recipes.loc[3, "instructions"] = instructions

# %%
ingredients_list = [
    ["Hard boiled eggs", "Cream cheese", "Ham"],
    ["6 large eggs", "16 oz pork sausage", "2 cup panko breadcrumbs (or regular bread crumbs)", "4 cups vegetable oil for frying"],
    ["8 large eggs", "1/4 cup milk or cream", "salt and pepper", "1/2 cup shredded jack cheese"],
    ["1 cup Fresh bread crumbs", "1 cup Boiled milk", "4 Eggs", "1 pch Salt"]]

eggs_recipes["ingredients_list"] = ingredients_list

# %%
eggs_recipes["Product"] = "eggs"

# %%
eggs_recipes
# Out:
#                         title  readyInMinutes  \
# 0         Square Deviled Eggs              45
# 1              The Scotch Egg              45
# 2  Easy Cheesy Scrambled Eggs              45
# 3               Bread Omlette              45
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/2Y8X7NKY/squar...
# 1  https://www.foodista.com/recipe/VS7W2DW5/the-s...
# 2  https://www.foodista.com/recipe/X5JCHLYL/easy-...
# 3  http://www.foodista.com/recipe/2M6MVKZT/bread-...
#
#                                                diets  \
# 0                          ['gluten free', 'primal']
# 1                                     ['dairy free']
# 2  ['gluten free', 'lacto ovo vegetarian', 'prima...
# 3                           ['lacto ovo vegetarian']
#
#                                         instructions  \
# 0  To make square hard boiled eggs, you'll need a...
# 1  Hard boil your eggs.  To get perfectly hard bo...
# ...

# %% [markdown]
# ## Flour Recipes

# %%
flour_recipes = pd.read_csv("flour_recipes.csv")
flour_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False         True
# 1        True  False       False      False        False  False         True
# 2        True  False       False      False        False  False         True
# 3       False  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                        26   no                  -1
# 1        False      False                        37   no                   5
# 2        False      False                        14   no                  -1
# 3        False      False                         2   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1            1669            2
# 1              40            1148            3
# 2              -1             359            2
# ...

# %%
flour_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "license", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
flour_recipes["instructions"] = flour_recipes["instructions"].apply(remove_html_tags)
flour_recipes["instructions"] = flour_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\1470705212.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   flour_recipes["instructions"] = flour_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions = "Preheat oven to 350F. Whisk together all of your crust ingredients until it becomes a grainy consistency. Take a spoon and press the graham crust into the foil making sure all of the edges and bottom are completely covered. Place into the oven and bake for 10-15 minutes until browned. Remove from oven and allow to cool for about an hour. For the filling, add all of your ingredients into a medium bowl and mix well for about 30 minutes, and then for 3 minutes on low. Place into the graham cracker crust, making sure all of the edges are filled. Bake in the oven for about 5-10 minutes, and then remove. Place onto a cooling rack for about 15 minutes, and then chill in the refrigerator for remaining 45 minutes to set. To serve, remove carefully from dish with foil and cut into bite sized squares."
flour_recipes.loc[0, "instructions"] = instructions

# %%
ingredients_list = [
    ["5 Tbsp unsalted butter (softened)",
    "2 Tbsp sugar",
    "2/3 cup all-purpose flour",
    "2 drops Lime essential oil (or 1 Tbsp grated lime zest if not using essential oils)",
    "1 cup crushed graham cracker crumbs",
    "1 (14 oz) can sweetened condensed milk",
    "10 drops Lime essential oil (or the juice from 4 limes)",
    "3 drops Lemon essential oil (or 2 Tbsp fresh lemon juice)",
    "2 egg yolks"],
    ["Butter", "White sugar", "All-purpose flour", "3 large fresh lemons, juiced", "Eggs", "Powdered sugar"],
    ["50g unsalted butter, softened", "2 cups self raising flour", "3/4 cup milk", "strawberry jam and cream"],
    ["3/4 cup all-purpose flour", "1/2 teaspoon salt", "3 eggs", "3/4 cup milk", "1/2 cup pan drippings from roast beef preferably"]
]

flour_recipes["ingredients_list"] = ingredients_list

# %%
flour_recipes["Product"] = "flour"

# %%
flour_recipes
# Out:
#                           title  readyInMinutes  \
# 0  Creamy Lime Pie Square Bites              45
# 1           The BEST Lemon Bars              45
# 2                Classic scones              45
# 3             Yorkshire Pudding              45
#
#                                            sourceUrl  \
# 0  http://www.pinkwhen.com/creamy-lime-pie-square...
# 1  https://www.pinkwhen.com/the-best-lemon-bars-r...
# 2  http://www.foodista.com/recipe/8R27PR6L/classi...
# 3  http://www.foodista.com/recipe/KPRQCDW7/yorksh...
#
#                       diets  \
# 0  ['lacto ovo vegetarian']
# 1  ['lacto ovo vegetarian']
# 2  ['lacto ovo vegetarian']
# 3                        []
#
#                                         instructions  \
# 0  Preheat oven to 350F. Whisk together all of yo...
# 1  Instructions  Preheat the oven to 350 degrees ...
# 2  Using fingertips, rub butter into flour until ...
# 3  Preheat oven to 400-450 F  depending on your o...
#
# ...

# %% [markdown]
# ## Ham Recipes

# %%
ham_recipes = pd.read_csv("ham_recipes.csv")
ham_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False        True       True        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         5   no                  -1
# 1        False      False                        10   no                  -1
# 2        False      False                        12   no                  -1
# 3        False      False                        11   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               4            3
# 1              -1               1           21
# 2              -1               2           13
# ...

# %%
ham_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
ham_recipes["instructions"] = ham_recipes["instructions"].apply(remove_html_tags)
ham_recipes["instructions"] = ham_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\1809123599.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   ham_recipes["instructions"] = ham_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions = 'Chop the meat and cheese into small pieces and place into a mixing bowl, add the jam and stir to combine. Lay out the egg roll wraps with 1 corner facing you; place about 2 Tbs. of the filling just above the bottom corner. Fold this bottom corner up over the filling, then fold in each side of the egg roll wrap then roll it up. When you roll up to the other corner use a little water on your finger and spread on the wrapper to seal the roll and corner together. Deep fry at 320 degrees, for about 3 minutes or until crispy and golden brown. Serve warm as is or sprinkle with powder sugar.'
ham_recipes.loc[0, "instructions"] = instructions

# %%
ingredients_list = [
    ["8 Egg Roll Wraps", "3 Deli Sliced Honey Ham", "3 Deli Sliced Black Forest Ham", "3 Deli Sliced Smoked Turkey", "3 Deli Sliced Baby Swiss Cheese",
    "5 tablespoons Strawberry Jam"],
    ["6 small potatoes, peeled and cut in half", "2 cups 14 oz. sauerkraut with pickling liquid", "1/2 teaspoon salt", "1/4 teaspoon black pepper",
     "water, enough to cover the potatoes in the pot", "1 cup cubed smoked turkey ham" , "1/4 cup olive oil", "1 garlic clove, finely chopped"],
    ["1/4 cup chopped pecans", "1 cup brown sugar", "1 tablespoon Chinese five-spice powder", "2 tablespoons butter, softened", 
    "1 5-pound good quality cooked ham", "2 medium onions, chopped"],
    ["4 long and thin sliced chicken breasts", "a slice of ham for each breast", "a slice of cheese of your choice", "50 grams of butter", "1 cup of white wine"]]

ham_recipes["ingredients_list"] = ingredients_list

# %%
ham_recipes["Product"] = "ham"

# %%
ham_recipes
# Out:
#                                                title  readyInMinutes  \
# 0                             Monte Cristo Egg Rolls              45
# 1    Potatoes With Sauerkraut and Crunchy Smoked Ham              45
# 2                                    Pecan-Baked Ham              45
# 3  Involtini Di Pollo - Ham and Cheese Stuffed Ch...              45
#
#                                            sourceUrl  \
# 0  http://www.foodista.com/recipe/WBB6376N/monte-...
# 1  http://www.foodista.com/recipe/5B4XKB4B/potato...
# 2  http://www.foodista.com/recipe/NXK3HKLD/pecan-...
# 3  https://www.foodista.com/recipe/2NYBLNQ4/invol...
#
#                                        diets  \
# 0                                         []
# 1  ['gluten free', 'dairy free', 'whole 30']
# 2                            ['gluten free']
# 3                  ['gluten free', 'primal']
#
#                                         instructions  \
# 0  Chop the meat and cheese into small pieces and...
# ...

# %% [markdown]
# ## Milk Recipes

# %%
milk_recipes = pd.read_csv("milk_recipes.csv")
milk_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1       False  False        True      False        False  False        False
# 2        True  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         6   no                  -1
# 1        False      False                         7   no                  -1
# 2        False      False                         7   no                  10
# 3        False      False                         0   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               1            3
# 1              -1              30            5
# 2              25              14            2
# ...

# %%
milk_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
milk_recipes["instructions"] = milk_recipes["instructions"].apply(remove_html_tags)
milk_recipes["instructions"] = milk_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\4052842988.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   milk_recipes["instructions"] = milk_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
    [
    "8 large egg yolks",
    "1 teaspoon vanilla extract",
    "1/2 cup white sugar",
    "1/2 can sweetened condensed milk",
    "1 tall can full cream evaporated milk",
    "For the caramel: 1 tablespoon white sugar for each mold"],
    ["1 cup fresh or frozen strawberries",
    "1 cup milk",
    "1/2 cup vanilla ice cream",
    "2 tablespoons sugar (adjust to taste)",
    "1/2 teaspoon vanilla extract"],
    ["1 1/2 cups all-purpose flour", 
    "1 1/2 teaspoons baking powder", 
    "1/4 teaspoon salt",
    "1/2 cup unsalted butter, softened",
    "1 cup granulated sugar",
    "2 large eggs",
    "1 teaspoon vanilla extract",
    "1/2 cup whole milk",
    "Nutella"],
    ["3 sheets of gelatin",
    "1/2 cup milk",
    "2 cups heavy cream",
    "1/2 cup sugar",
    "1 vanilla",
    "4 ounces dark chocolate",
    "3/4 cup heavy cream"]]

milk_recipes["ingredients_list"] = ingredients_list

# %%
milk_recipes["Product"] = "milk"

# %%
milk_recipes
# Out:
#                                                title  readyInMinutes  \
# 0                          Leche Flan (Caramel Flan)              45
# 1                          Homemade Strawberry Shake              45
# 2  Nutella Buttercream Cupcakes with Hidden Cadbu...              35
# 3         Vanilla Panna Cotta with Chocolate Ganache              45
#
#                                            sourceUrl  \
# 0  http://www.foodista.com/recipe/SV8HNT37/leche-...
# 1  http://www.pinkwhen.com/homemade-strawberry-sh...
# 2  https://www.pinkwhen.com/nutella-buttercream-c...
# 3  http://www.foodista.com/recipe/RHHSKBJQ/vanill...
#
#                                                diets  \
# 0            ['gluten free', 'lacto ovo vegetarian']
# 1                                    ['gluten free']
# 2  ['gluten free', 'lacto ovo vegetarian', 'ketog...
# 3                          ['gluten free', 'primal']
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Mushrooms Recipes

# %%
mushrooms_recipes = pd.read_csv("mushrooms_recipes.csv")
mushrooms_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True       False       True        False  False        False
# 1        True   True        True       True        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints       gaps  \
# 0        False      False                         0         no
# 1        False      False                         3  GAPS_FULL
# 2        False      False                        10         no
# 3        False      False                         5         no
#
#    preparationMinutes  cookingMinutes  aggregateLikes  healthScore  \
# 0                  -1              -1              11           52
# 1                  -1              -1               8           32
# ...

# %%
mushrooms_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
mushrooms_recipes["instructions"] = mushrooms_recipes["instructions"].apply(remove_html_tags)
mushrooms_recipes["instructions"] = mushrooms_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\3201741180.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   mushrooms_recipes["instructions"] = mushrooms_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
["18 mushroom caps",
"1 (6 1/2 ounce) package Alouette garlic & herbs or (6 1/2 ounce) package Alouette spinach & artichokes",
"3 tablespoons seasoned bread crumbs"],
["1/4 cup extra virgin olive oil",
"2 cloves garlic, crushed",
"500g button mushrooms, quartered",
"1/4 teaspoon dried chili flakes",
"2 teaspoons salt flakes",
"1/4 cup finely sliced flat-leaf parsley",
"Crusty bread, for serving"],
["3/4 lb portobello mushrooms",
"1 clove garlic",
"2 tbsp olive oil",
"Salt and pepper to taste",
"1/2 tsp dried thyme",
"1/2 tbsp butter",
"1 tbsp parmesan grated",
"3 tbsp mozzarella grated"],
["1 1/2 pounds variety of mushrooms",
"2 garlic cloves",
"Olive oil",
"Salt and pepper",
"Red wine vinegar",
"Fresh chopped parsley"]]

mushrooms_recipes["ingredients_list"] = ingredients_list

# %%
mushrooms_recipes["Product"] = "mushrooms"

# %%
mushrooms_recipes
# Out:
#                              title  readyInMinutes  \
# 0  Alouette® Stuffed Mushroom Caps              45
# 1              Funghetti Trifolati              45
# 2              Baked Mushroom Caps              45
# 3          Grilled Mushrooms Salad              45
#
#                                            sourceUrl  \
# 0  http://www.foodista.com/recipe/8LZ2BYQT/alouet...
# 1  http://www.foodista.com/recipe/QWM2B5CV/funghe...
# 2  http://www.foodista.com/recipe/WMBPN6F8/baked-...
# 3  http://www.foodista.com/recipe/QZGWCFZY/grille...
#
#                                                diets  \
# 0    ['dairy free', 'lacto ovo vegetarian', 'vegan']
# 1  ['gluten free', 'dairy free', 'paleolithic', '...
# 2                                    ['gluten free']
# 3                          ['gluten free', 'primal']
#
#                                         instructions  \
# 0  Preheat oven to 375 F.Place mushroom caps holl...
# 1  First, in a large skillet let the oil get hot....
# ...

# %% [markdown]
# ## Oliveoil Recipes

# %%
oliveoil_recipes = pd.read_csv("oliveoil_recipes.csv")
oliveoil_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False        False
# 1        True  False       False      False        False  False        False
# 2        True  False        True      False        False  False        False
# 3       False  False        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints       gaps  \
# 0        False      False                        13         no
# 1        False      False                        10         no
# 2        False      False                         8         no
# 3        False      False                        13  GAPS_FULL
#
#    preparationMinutes  cookingMinutes  aggregateLikes  healthScore  \
# 0                  -1              -1               4            2
# 1                  -1              -1               3           20
# ...

# %%
oliveoil_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
oliveoil_recipes["instructions"] = oliveoil_recipes["instructions"].apply(remove_html_tags)
oliveoil_recipes["instructions"] = oliveoil_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\1980580085.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   oliveoil_recipes["instructions"] = oliveoil_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
["20 Kalamata olives",
"20 Green manzanilla olives",
"6-8 teaspoons of the olive juices (combined)",
"2 Naan breads (Stonefire brand)",
"5-6 oz. fresh mozzarella cheese (cut into small pieces)",
"1 TBS extra virgin olive oil",
"1/2 cup arugula",
"1 drizzle balsamic vinegar",
"1 drizzle extra virgin olive oil"],
["2 cups (475 ml) all-purpose unbleached flour",
"2 cups (475 ml) whole wheat flour",
"1/2 cup (130 ml) warm water (warmer than room temp but not uncomfortable to the touch)",
"1/2 package (1 teaspoon/5ml) active dry yeast",
"1 cup (235 ml) warm water (same as the first)",
"1 pinch of good salt",
"1 tablespoon (15 ml) olive oil",
"Sliced olives",
"Crumbled feta",
"Fresh basil, cut into thin ribbons",
"Salt"],
["5 large ripe tomatoes",
"1 large red onion, sliced thinly",
"1 large cucumber",
"1/4 pound Greek feta",
"1 dozen Kalamata olives",
"High-quality extra virgin olive oil"],
["1 cup (approx. 5 oz or 140 g) pitted olives",
"1 tablespoon fresh oregano leaves",
"2 cloves garlic (add more if you like it really garlicky)",
"2 tablespoons extra virgin olive oil",
"1-2 zucchini",
"2 cans sardines"]]

oliveoil_recipes["ingredients_list"] = ingredients_list

# %%
oliveoil_recipes["Product"] = "oliveoil"

# %%
oliveoil_recipes
# Out:
#                                               title  readyInMinutes  \
# 0                          Olive Tapenade Flatbread              20
# 1                    Basil, Olive and Feta Foccacia              45
# 2                                  Greek Side Salad              15
# 3  Garlic Oregano Olive Tapenade [Paleo, AIP, Keto]              45
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/JN3RWH2P/olive...
# 1  https://www.foodista.com/recipe/33CWWLYH/basil...
# 2  http://www.foodista.com/recipe/QZ2D5V6N/greek-...
# 3  https://www.foodista.com/recipe/P47LT3HY/garli...
#
#                                                diets  \
# 0                           ['lacto ovo vegetarian']
# 1                           ['lacto ovo vegetarian']
# 2  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 3  ['gluten free', 'dairy free', 'paleolithic', '...
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Pasta Recipes

# %%
pasta_recipes = pd.read_csv("pasta_recipes.csv")
pasta_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1        True  False       False      False        False  False        False
# 2       False  False       False      False        False  False        False
# 3       False  False       False       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                        15   no                   5
# 1        False      False                         4   no                  -1
# 2        False      False                        24   no                  -1
# 3        False      False                         1   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              30             163           27
# 1              -1               3            5
# 2              -1               1           12
# ...

# %%
pasta_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
pasta_recipes["instructions"] = pasta_recipes["instructions"].apply(remove_html_tags)
pasta_recipes["instructions"] = pasta_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\393983203.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   pasta_recipes["instructions"] = pasta_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
["Pasta",
"Fresh tomatoes",
"Garlic",
"Onion",
"Fresh Basil",
"Parmesan Cheese",
"Olive Oil",
"Salt"],
["12 ounces penne pasta",
"1 cup basil leaves",
"4 ounces Goat Cheese",
"2 tablespoons olive oil",
"Salt and pepper to taste"],
["4 ounces linguini (dry)",
"1/2 cup cooked chickpeas",
"1 slice bacon (black peppered bacon is a favorite)",
"Cup olive oil",
"1/4 diced red pepper (optional)",
"As desired Parmesan or Asiago cheese"],
["150 grams Spaghetti",
"1 can Smoked salmon",
"10 Medium prawns - shelled and cleaned, seasoned with a little salt and pepper",
"1 tablespoon Garlic - chopped or sliced",
"2 tablespoons Fresh dill - roughly cut",
"50-80mls Extra Virgin Olive oil"]]

pasta_recipes["ingredients_list"] = ingredients_list

# %%
title = "Bruschetta Style Pork & Pasta"
pasta_recipes.loc[0, "title"] = title

# %%
pasta_recipes["Product"] = "pasta"

# %%
pasta_recipes
# Out:
#                                      title  readyInMinutes  \
# 0            Bruschetta Style Pork & Pasta              35
# 1         Penne with Goat Cheese and Basil              45
# 2       Linguine With Chick Peas and Bacon              45
# 3  Spaghetti With Smoked Salmon and Prawns              45
#
#                                            sourceUrl  \
# 0       http://www.pinkwhen.com/make-dinner-tonight/
# 1  https://www.foodista.com/recipe/6TFN786K/penne...
# 2  http://www.foodista.com/recipe/3D38JB7D/lingui...
# 3  http://www.foodista.com/recipe/8LJJKXX6/spaghe...
#
#                            diets  \
# 0                             []
# 1       ['lacto ovo vegetarian']
# 2                             []
# 3  ['dairy free', 'pescatarian']
#
#                                         instructions  \
# 0  wash and rinse pork chops and place into the s...
# 1  Cook pasta according to package directions Arr...
# 2  If not done prior, soak and boil the Chick Pea...
# ...

# %% [markdown]
# ## Potatoes Recipes

# %%
potatoes_recipes = pd.read_csv("potatoes_recipes.csv")
potatoes_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True       False       True        False  False         True
# 1        True   True        True       True        False  False        False
# 2        True   True        True       True         True  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                        20   no                  -1
# 1        False      False                         8   no                  -1
# 2        False      False                        43   no                  -1
# 3        False      False                        27   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1            1669           44
# 1              -1               4           10
# 2              -1               1           85
# ...

# %%
potatoes_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
potatoes_recipes["instructions"] = potatoes_recipes["instructions"].apply(remove_html_tags)
potatoes_recipes["instructions"] = potatoes_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\3405110242.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   potatoes_recipes["instructions"] = potatoes_recipes["instructions"].str.replace(r'\n', ' ')

# %%
instructions =  "Take your sliced fries and place them in a large mixing bowl. Add in your basil and garlic powder and mix well, coating them as evenly as possible. Add in the flour and again mix well. Heat up your vegetable oil and cook until floating on top and very lightly brown. Remove from oil and place on napkins to remove excess oil. Then sprinkle with a dash of garlic salt and parsley to while still hot. Serve immediately."
potatoes_recipes.loc[0, "instructions"] = instructions

# %%
ingredients_list = [
["4 sliced, fresh potatoes",
"Vegetable oil",
"1/4 cup basil",
"1 cup flour",
"1/4 garlic powder",
"Garlic salt with parsley (to sprinkle)"],
["3-4 large red potatoes washed and cut into wedges",
"seasoning salt",
"garlic powder", 
"onion powder",
"pepper",
"1/4 cup canola oil"],
["6 Medium Size Potatoes (washed and cut into cubes)",
"Cup of Cold Pressed Olive Oil",
"1/2 Onion Minced",
"1 teaspoon of Pepper",
"1 tablespoon of Salt",
"2 cloves of Garlic Minced (I use my garlic press)"],
["1 1/2 cups cream",
"1/4 teaspoon salt and pepper",
"2 pounds russet potatoes, peeled and cubed",
"1 stick Butter",
"1/4 cup Freshly grated parmesan cheese"]]

potatoes_recipes["ingredients_list"] = ingredients_list

# %%
potatoes_recipes["Product"] = "potatoes"

# %%
potatoes_recipes
# Out:
#                                     title  readyInMinutes  \
# 0  Homemade Garlic and Basil French Fries              45
# 1                 Pan Fried Potato Wedges              20
# 2                           Oven Potatoes              45
# 3                Parmesan Mashed Potatoes              45
#
#                                            sourceUrl  \
# 0     http://www.pinkwhen.com/homemade-french-fries/
# 1  https://www.foodista.com/recipe/ZMHYGRRP/pan-f...
# 2  http://www.foodista.com/recipe/VR6FXHQX/oven-p...
# 3  http://www.foodista.com/recipe/WRQP2BQF/parmes...
#
#                                                diets  \
# 0    ['dairy free', 'lacto ovo vegetarian', 'vegan']
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...
# 2  ['gluten free', 'dairy free', 'lacto ovo veget...
# 3                                    ['gluten free']
#
#                                         instructions  \
# 0  Take your sliced fries and place them in a lar...
# ...

# %% [markdown]
# ## Rice Recipes

# %%
rice_recipes = pd.read_csv("rice_recipes.csv")
rice_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True        True       True        False  False        False
# 1        True  False        True      False        False  False        False
# 2        True  False       False      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False       True                        12   no                  -1
# 1        False      False                         6   no                  -1
# 2        False      False                        26   no                  -1
# 3        False      False                         5   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               1            1
# 1              -1               1            0
# 2              -1               1           35
# ...

# %%
rice_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
rice_recipes["instructions"] = rice_recipes["instructions"].apply(remove_html_tags)
rice_recipes["instructions"] = rice_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\943878611.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   rice_recipes["instructions"] = rice_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
["1/3 cup long-grain black rice",
"1 14-ounce can light coconut milk",
"1/2 cup brown sugar",
"Pinch of salt",
"A few cardamom pods, cinnamon sticks, or saffron"],
["1 1/2 tablespoons unsalted butter",
"1 small onion, finely chopped",
"1 teaspoon cumin seeds",
"1 1/2 cups basmati rice, rinsed well",
"1 teaspoon salt",
"2 1/4 cups water"],
["150 grams Cooked round grain rice",
"Milk",
"5 grams Fresh yeast",
"40 grams Honey",
"250 grams German flour",
"Salt"],
["2 boxes of Wild Rice",
"1 package regular-size Fresh sliced Cremini or button mushrooms",
"1/2 stick butter",
"1 package small real bacon bits pieces",
"4 green onions, sliced"]]

rice_recipes["ingredients_list"] = ingredients_list

# %%
rice_recipes["Product"] = "rice"

# %%
rice_recipes
# Out:
#                                                title  readyInMinutes  \
# 0  Cardamon Infused Black Rice Pudding with Cocon...              45
# 1                   Cumin-Scented Basmati Rice Pilaf              45
# 2                                   Rice Honey Bread              45
# 3     Wild Rice With Bacon, Mushrooms & Green Onions              45
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/PQMPK3Y5/carda...
# 1  https://www.foodista.com/recipe/RYNTB4NP/cumin...
# 2  http://www.foodista.com/recipe/VPC587GN/rice-h...
# 3  https://www.foodista.com/recipe/H4TVGTQM/wild-...
#
#                                                diets  \
# 0  ['gluten free', 'dairy free', 'lacto ovo veget...
# 1            ['gluten free', 'lacto ovo vegetarian']
# 2                           ['lacto ovo vegetarian']
# 3                       ['gluten free', 'ketogenic']
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Salad Recipes

# %%
salad_recipes = pd.read_csv("salad_recipes.csv")
salad_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True        True       True         True  False        False
# 1        True   True        True       True        False  False        False
# 2       False  False        True       True        False  False        False
# 3        True   True       False       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints       gaps  \
# 0        False      False                         5         no
# 1        False      False                         0         no
# 2        False       True                         3  GAPS_FULL
# 3        False      False                         4         no
#
#    preparationMinutes  cookingMinutes  aggregateLikes  healthScore  \
# 0                  -1              -1              19           83
# 1                  -1              -1               1           30
# ...

# %%
salad_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
salad_recipes["instructions"] = salad_recipes["instructions"].apply(remove_html_tags)
salad_recipes["instructions"] = salad_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\3798669451.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   salad_recipes["instructions"] = salad_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
    ["1 tablespoon olive oil",
    "1 bunch curly kale, stems removed and chopped",
    "3 cloves garlic, minced",
    "3 tablespoons balsamic vinegar"],
    ["1 large bunch of kale, washed and trimmed, chopped into bite-sized pieces",
    "1/2 red onion, sliced thinly",
    "1 tablespoon olive oil",
    "2 cloves garlic, minced"],
    ["1 Large Lemon, Juiced",
    "1/2 Cup extra Virgin Olive Oil",
    "2 Ounces Black Truffles (or more if you have them!)",
    "1 teaspoon Kosher Salt",
    "1 head romaine lettuce",
    "8 ounces shredded duck confit leg and thigh (optional)"],
    ["Inch Kale, called cavolo nero tuscany",
    "Country-style bread, sliced for toast, thickly",
    "Extra Virgin Olive oil",
    "1 Garlic Clove",
    "Salt"]]

salad_recipes["ingredients_list"] = ingredients_list

# %%
salad_recipes["Product"] = "salad"

# %%
salad_recipes
# Out:
#                         title  readyInMinutes  \
# 0               Garlicky Kale              45
# 1         Kale With Red Onion              45
# 2  Black Truffle Caesar Salad              45
# 3             Kale Bruschetta              45
#
#                                            sourceUrl  \
# 0  http://www.foodista.com/recipe/J2FTJBF7/garlic...
# 1  https://www.foodista.com/recipe/XM62FP2Y/kale-...
# 2  https://www.foodista.com/recipe/5TPQ3LJB/black...
# 3  http://www.foodista.com/recipe/3MK8JYZR/kale-b...
#
#                                                diets  \
# 0  ['gluten free', 'dairy free', 'paleolithic', '...
# 1  ['gluten free', 'dairy free', 'paleolithic', '...
# 2  ['gluten free', 'dairy free', 'paleolithic', '...
# 3    ['dairy free', 'lacto ovo vegetarian', 'vegan']
#
#                                         instructions  \
# 0  Heat the olive oil in a large pot over medium ...
# 1  In a cast iron pan, over medium low heat, heat...
# ...

# %% [markdown]
# ## Salmon Recipes

# %%
salmon_recipes = pd.read_csv("salmon_recipes.csv")
salmon_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True      False        False  False        False
# 1       False  False       False       True        False  False        False
# 2       False  False        True      False        False  False        False
# 3       False  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         8   no                  -1
# 1        False      False                         4   no                  -1
# 2        False      False                         5   no                  -1
# 3        False      False                        24   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore   creditsText    sourceName  \
# 0              -1               7           44  foodista.com  foodista.com
# ...

# %%
salmon_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "dishTypes"], inplace = True, axis = 1)

# %%
salmon_recipes["instructions"] = salmon_recipes["instructions"].apply(remove_html_tags)
salmon_recipes["instructions"] = salmon_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\110045283.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   salmon_recipes["instructions"] = salmon_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
    ["1 pound frozen green beans",
    "1 cup frozen pearl onions",
    "1 teaspoon olive oil",
    "2 tablespoon unsalted butter + ½ teaspoon",
    "¼ cup chicken stock, sodium free",
    "1 teaspoon brown sugar",
    "salt and pepper",
    "Salmon steaks, skinless"],
    ["1 pound wild salmon fillet",
    "1/4 red onion, diced",
    "1 teaspoon capers",
    "1 egg",
    "1/2 cup panko, plain crackers, or gluten-free bread crumbs"],
    ["4 tortilla wraps",
    "4 tablespoons large of fresh ricotta",
    "rucola leaves",
    " fresh basil leaves",
    "smoked salmon"],
    ["4 salmon fillets",
    "butter",
    "freshly squeezed lime juice (to taste)"
    "1 clove garlic, minced"
    "500g / 1 lb asparagus spears"
    "Olive oil"
    "Salt and pepper"]]

salmon_recipes["ingredients_list"] = ingredients_list

# %%
instructions = "In a frying pan, melt the butter over medium-high heat. Once your pan is piping hot, carefully place the salmon (lay it away from you, not towards you or you might get burnt by the butter) and cook 3-5 minutes on each side, until salmon has cooked through. Serve immediately, drizzled with sauce.For the brown butter lime sauce: Place the butter in a small saucepan and allow to melt over medium heat, stirring occasionally, until the butter is fragrant and has turned slightly brown (but not burnt). Remove from the heat and allow to cool down a little bit before pouring into a blender along with the lime juice and garlic. Season with salt and pepper and blend until well combined. Pour sauce back into the pan, straining it if need be. You may need to rewarm it on low heat before serving.For the roasted asparagus: Preheat your oven to 200C/400F and line a roasting tin with aluminium foil. Cut off the asparagus ends if they are tough. Drizzle with olive oil, salt and pepper. Toss the spears to coat them evenly. Arrange the asparagus spears in a single layer. Depending on your oven and the thickness of the asparagus, roast for 10-12 minutes, or until the asparagus are tender when pierced with a fork"
salmon_recipes.loc[3, "instructions"] = instructions

# %%
salmon_recipes["Product"] = "salmon"

# %%
salmon_recipes
# Out:
#                                                title  readyInMinutes  \
# 0           Green Beans with Pearl Onions and Salmon              45
# 1                                  Wild Salmon Cakes              45
# 2                      Smoked Salmon & Ricotta Wraps              10
# 3  Pan-seared salmon with brown butter lime sauce...              45
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/PDS5KZWD/green...
# 1  https://www.foodista.com/recipe/TQ7FYHL4/wild-...
# 2  http://www.foodista.com/recipe/XKTZLGJY/sophie...
# 3  http://www.foodista.com/recipe/8LXMLY2P/pan-se...
#
#                                                diets  \
# 0                     ['gluten free', 'pescatarian']
# 1                      ['dairy free', 'pescatarian']
# 2                     ['gluten free', 'pescatarian']
# 3  ['gluten free', 'primal', 'pescatarian', 'keto...
#
#                                         instructions  \
# ...

# %% [markdown]
# ## Spinach Recipes

# %%
spinach_recipes = pd.read_csv("spinach_recipes.csv")
spinach_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False        True      False        False  False        False
# 2        True  False       False      False        False  False        False
# 3       False  False       False      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                         3   no                  -1
# 1        False      False                         5   no                  -1
# 2        False      False                        13   no                  -1
# 3        False      False                         4   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1               7           18
# 1              -1               7           48
# 2              -1               2           45
# ...

# %%
spinach_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
spinach_recipes["instructions"] = spinach_recipes["instructions"].apply(remove_html_tags)
spinach_recipes["instructions"] = spinach_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\1017964139.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   spinach_recipes["instructions"] = spinach_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
   ["Small personal skillet",
    "Spinach leaves",
    "Cherry tomatoes, halved",
    "2-3 lightly beaten eggs",
    "Salt/pepper (optional)"],
    ["1 small frozen ripe banana, peeled",
    "2 cups baby spinach",
    "1 tablespoon Peanut Butter",
    "3/4 cup unsweetened vanilla almond milk",
    "1/2 cup plain fat-free Greek yogurt"],
    ["1 roll of Puff Pastry",
    "1 red Bell Pepper, sliced",
    "1 cup Spinach, if frozen, thaw and drain",
    "1 cup sliced mushrooms",
    "1/4 cup crumbled goat cheese",
    "Salt and pepper to taste"],
    ["4 boxes frozen spinach",
    "2 boxes cornbread stuffing mix",
    "2 sticks butter (your call)",
    "1 1/2 cups shredded Parmesan cheese",
    "6 eggs"]]

spinach_recipes["ingredients_list"] = ingredients_list

# %%
instructions = "To get started, place a drop of olive oil in the bottom of the skillet and rub it around. Grab a few spinach leaves and start wilting them over medium heat for 20-30 seconds. Add the cherry tomato halves and then pour the egg mixture over the tomatoes and spinach. Once the mixture is almost completely done, place it under the broiler for a few seconds to finish cooking the top. Sprinkle the top with a little salt and pepper and you are ready to eat! You could also try adding more items to your frittata to make it even more tasty! Try adding green onion tops, diced turkey bacon, a little cheese…all of these things just add more flavor"
spinach_recipes.loc[0, "instructions"] = instructions

# %%
spinach_recipes["Product"] = "spinach"

# %%
spinach_recipes
# Out:
#                                 title  readyInMinutes  \
# 0  Simple Spinach and Tomato Frittata              45
# 1       Skinny Green Monster Smoothie              45
# 2     Vegetable Tart With Goat Cheese              25
# 3     Becky Bergstrom's Spinach Balls              45
#
#                                            sourceUrl  \
# 0  http://www.pinkwhen.com/spinach-and-tomato-fri...
# 1  https://www.foodista.com/recipe/ZYDRZ3CV/skinn...
# 2  http://www.foodista.com/recipe/NGWYYZNV/vegeta...
# 3  http://www.foodista.com/recipe/HZQCYNQV/becky-...
#
#                       diets  \
# 0                        []
# 1           ['gluten free']
# 2  ['lacto ovo vegetarian']
# 3             ['ketogenic']
#
#                                         instructions  \
# 0  To get started, place a drop of olive oil in t...
# 1  Place all ingredients in a blender and blend u...
# 2  Pre-heat oven to 350F. Roll out puff pastry on...
# 3  Thaw the spinach and chop it up so its not str...
#
# ...

# %% [markdown]
# ## Veggies Recipes

# %%
veggies_recipes = pd.read_csv("veggies_recipes.csv")
veggies_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False       True        False  False        False
# 1        True  False        True      False         True  False        False
# 2        True  False        True      False        False  False        False
# 3        True   True        True       True        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints gaps  preparationMinutes  \
# 0        False      False                        17   no                  -1
# 1        False      False                         4   no                  -1
# 2        False      False                         0   no                  -1
# 3        False       True                         9   no                  -1
#
#    cookingMinutes  aggregateLikes  healthScore  \
# 0              -1              24           39
# 1              -1               1          100
# 2              -1               1           24
# ...

# %%
veggies_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
veggies_recipes["instructions"] = veggies_recipes["instructions"].apply(remove_html_tags)
veggies_recipes["instructions"] = veggies_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\2303248236.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   veggies_recipes["instructions"] = veggies_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
    ["1 package (15 ounces) refrigerated pie crust (2 crusts)",
    "1 can (10 1/2 ounces) Chicken Gravy",
    "3 cups cooked cut-up vegetables *",
    "2 ounces cans (4.5 each) Swanson Premium White Chunk Chicken Breast in Water, drained"],
    ["2 cups plain low-fat yogurt",
    "1 package frozen chopped spinach, thawed & drained (10 oz)",
    "1/4 cup fresh onion, minced",
    "1 envelope Lipton vegetable recipe soup mix (0.9 oz)",
    "Assorted raw vegetables for dipping"],
    ["1 pound Peas",
    "1 package 5.3 oz. Chavrie fresh goat cheese, Pyramid",
    "1 teaspoon Chopped tarragon"],
    ["4 inches sheets of nori (dried seaweed), cut in half",
    "4 cups sushi rice",
    "2 Japanese cucumbers, cut into long sticks"]]

veggies_recipes["ingredients_list"] = ingredients_list

# %%
veggies_recipes["Product"] = "veggies"

# %%
veggies_recipes
# Out:
#                                       title  readyInMinutes  \
# 0              4 Ingredient Chicken Pot Pie              45
# 1                             Vegetable Dip              45
# 2  Peas And Tarragon With Fresh Goat Cheese              45
# 3                                Kappa Maki              45
#
#                                            sourceUrl  \
# 0  https://www.foodista.com/recipe/V7VFKMB2/chick...
# 1  http://www.foodista.com/recipe/WMHFXKKF/vegeta...
# 2  https://www.foodista.com/recipe/SNJ64XV8/peas-...
# 3  http://www.foodista.com/recipe/VJ3JTZWL/kappa-...
#
#                                                diets  \
# 0                                     ['dairy free']
# 1  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 2  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 3  ['gluten free', 'dairy free', 'lacto ovo veget...
#
#                                         instructions  \
# 0  Let the pie crusts stand at room temperature f...
# ...

# %% [markdown]
# ## Yogurt Recipes

# %%
yogurt_recipes = pd.read_csv("yogurt_recipes.csv")
yogurt_recipes
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1        True  False        True      False        False  False        False
# 2        True  False        True      False        False  False        False
# 3        True  False        True      False        False  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints    gaps  \
# 0        False      False                         2  GAPS_3
# 1        False      False                         1      no
# 2        False      False                         2  GAPS_6
# 3        False      False                         2      no
#
#    preparationMinutes  cookingMinutes  aggregateLikes  healthScore  \
# 0                  -1              -1              95            4
# 1                  -1              -1               5            0
# 2                  -1              -1               1           11
# ...

# %%
yogurt_recipes.drop(["vegetarian", "vegan", "glutenFree", "veryHealthy", "cheap", "veryPopular", "sustainable", "lowFodmap", "weightWatcherSmartPoints",
                    "gaps", "preparationMinutes", "cookingMinutes", "aggregateLikes", "healthScore", "creditsText", "sourceName", "pricePerServing",
                     "extendedIngredients", "id", "servings", "image", "imageType", "summary", "cuisines", "occasions", "winePairing", "analyzedInstructions",
                       "originalId","spoonacularSourceUrl", "dairyFree", "license", "dishTypes"], inplace = True, axis = 1)

# %%
yogurt_recipes["instructions"] = yogurt_recipes["instructions"].apply(remove_html_tags)
yogurt_recipes["instructions"] = yogurt_recipes["instructions"].str.replace(r'\n', ' ')
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11160\80808722.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   yogurt_recipes["instructions"] = yogurt_recipes["instructions"].str.replace(r'\n', ' ')

# %%
ingredients_list = [
    ["1 cup plain Greek yogurt",
    "2/3 cup caramelized onions (I used the slow cooker ones I keep on hand)",
    "About 2 tablespoons chopped fresh chives",
    "Salt, to taste"],
    ["1 tub of vanilla Balkan-style yogurt, 650g",
    "2 tablespoons of amaretto cream (keep cold)",
    "2 tablespoons of dulce de leche, or caramel, or a few caramel squares"],
    ["200 milliliters of Plain/Flavored Yogurt",
    "Handful of Fresh Blueberries",
    "10 Strawberries"],
    ["1 teaspoon low-fat yogurt",
    "1/4 cup Balsamic vinegar",
    "1/4 cup Olive oil",
    "1 teaspoon Dijon mustard",
    "1/8 teaspoon White pepper"]]

yogurt_recipes["ingredients_list"] = ingredients_list

# %%
instructions = "Put the yogurt in a bowl. Add the caramelized onions and salt to the yogurt and mix well. Toss in the chives and stir again. Let sit at least an hour (but overnight is better) so that the onion flavor seeps into all the yogurt."
yogurt_recipes.loc[0, "instructions"] = instructions

# %%
instructions = "In a small mixing bowl, whisk together the yogurt, balsamic, mustard, salt and pepper. Add the oil and whisk thoroughly to combine. Continue whisking until the dressing is fully emulsified."
yogurt_recipes.loc[3, "instructions"] = instructions

# %%
yogurt_recipes["Product"] = "yogurt"

# %%
yogurt_recipes
# Out:
#                                            title  readyInMinutes  \
# 0                          Caramelized Onion Dip              45
# 1  Dulce De Leche Swirled Amaretto Frozen Yogurt              45
# 2          [valentine's Dessert] Melt Your Heart              45
# 3                  Balsamic Vinaigrette Dressing              45
#
#                                            sourceUrl  \
# 0  http://fullbellysisters.blogspot.com/2011/06/c...
# 1  https://www.foodista.com/recipe/VBVWJCQW/dulce...
# 2  https://www.foodista.com/recipe/2NX3P7FC/valen...
# 3  https://www.foodista.com/recipe/8S6TT3RH/balsa...
#
#                                                diets  \
# 0  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 1            ['gluten free', 'lacto ovo vegetarian']
# 2  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 3  ['gluten free', 'lacto ovo vegetarian', 'primal']
#
#                                         instructions  \
# ...

# %%
recipes = [apple_recipes, avocado_recipes, beans_recipes, bread_recipes, cheese_recipes, chicken_recipes, eggs_recipes, flour_recipes, 
        ham_recipes, milk_recipes, mushrooms_recipes, oliveoil_recipes, pasta_recipes, potatoes_recipes, rice_recipes, salad_recipes,
        salmon_recipes, spinach_recipes, veggies_recipes, yogurt_recipes]

recipes_df = pd.concat(recipes, ignore_index = True)

# %%
recipes_df
# Out:
#                                             title  readyInMinutes  \
# 0               Slow Cooker Apple Pork Tenderloin              45
# 1                          Slow Cooked Applesauce              45
# 2                     Baked Cinnamon Apple Slices              45
# 3     Easiest Breakfast Ever: Sunny Fruit Parfait              45
# 4   Avocado Tomato & Mozzarella Panini/sandwiches              45
# ..                                            ...             ...
# 75                                     Kappa Maki              45
# 76                          Caramelized Onion Dip              45
# 77  Dulce De Leche Swirled Amaretto Frozen Yogurt              45
# 78          [valentine's Dessert] Melt Your Heart              45
# 79                  Balsamic Vinaigrette Dressing              45
#
#                                             sourceUrl  \
# 0   http://www.pinkwhen.com/slow-cooker-apple-pork...
# 1   https://www.foodista.com/recipe/XB3V6NRQ/slow-...
# ...

# %%
recipes_df.drop("diets", inplace = True, axis = 1)

# %%
new_column_names = ["recipe_title", "preparation_time", "recipe_url", "instructions", "ingredients_list", "name_id"]
recipes_df.columns = new_column_names

# %%
recipes_df
# Out:
#                                      recipe_title  preparation_time  \
# 0               Slow Cooker Apple Pork Tenderloin                45
# 1                          Slow Cooked Applesauce                45
# 2                     Baked Cinnamon Apple Slices                45
# 3     Easiest Breakfast Ever: Sunny Fruit Parfait                45
# 4   Avocado Tomato & Mozzarella Panini/sandwiches                45
# ..                                            ...               ...
# 75                                     Kappa Maki                45
# 76                          Caramelized Onion Dip                45
# 77  Dulce De Leche Swirled Amaretto Frozen Yogurt                45
# 78          [valentine's Dessert] Melt Your Heart                45
# 79                  Balsamic Vinaigrette Dressing                45
#
#                                            recipe_url  \
# 0   http://www.pinkwhen.com/slow-cooker-apple-pork...
# ...

# %%
recipes_df.to_csv("recipes.csv", index=False)
